# %% [markdown]
# <a href="https://colab.research.google.com/github/SadeemAlasiri/Exme/blob/main/week2_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd # import Libraries
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
df=pd.read_csv('/content/RTA_Dataset.csv')#lodaing data

# %%
df # show the data set
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.info()#shoe the informatiomn of the data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df.head(4)#print the first 4
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 0            Owner              Above 10yr  ...   Going straight
# 1            Owner                 5-10yrs  ...   Going straight
# ...

# %%
df.tail(3)#print the last 3
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12313            Bajaj            Owner                  2-5yrs  ...
# 12314  Lorry (41?100Q)            Owner                  2-5yrs  ...
# 12315            Other            Owner                  2-5yrs  ...
#
#       Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 12313            Other  Driver or rider            Male                31-50
# ...

# %%
df.sample(6)# print random
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 1348  17:05:00     Tuesday            Over 51          Male
# 9999  17:25:00      Friday              31-50          Male
# 7892  19:49:00   Wednesday              31-50          Male
# 6961  22:40:00      Sunday              18-30          Male
# 5187  20:52:00     Tuesday              18-30          Male
# 105   16:10:00      Monday            Over 51          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 1348  Junior high school                Employee             5-10yr
# 9999         High school                Employee              2-5yr
# 7892  Junior high school                Employee             5-10yr
# 6961             Unknown                   Owner         Above 10yr
# 5187  Junior high school                Employee             5-10yr
# 105   Junior high school                Employee             5-10yr
#
# ...

# %%
df.describe()# summary statistics fromthe max and min and coun..
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                  2889.000000           2889.000000
# mean                      2.011076              1.529249
# std                       0.635308              0.993012
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df.isna().sum()#show if ther null
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df['Owner_of_vehicle'].value_counts()
# Out:
# Owner_of_vehicle
# Owner           2573
# Governmental     228
# Organization      81
# Other              7
# Name: count, dtype: int64

# %%
df['Number_of_casualties'].isna().sum()#show the null of the colme Number_of_casualties
# Out:
# 0

# %%
df['Number_of_vehicles_involved'].isna().sum()#show the null of the colme Number_of_casualties
# Out:
# 0

# %%
df.duplicated().sum()# print if ther any duplicated
# Out:
# 0

# %%
df=df.dropna()# drop the null

# %%
df.isna().sum()# print if there inay null
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 8      17:20:00      Friday              18-30          Male
# 9      17:20:00      Friday              18-30          Male
# 12     17:45:00    Thursday              18-30          Male
# 13     17:45:00    Thursday              31-50          Male
# 14     17:45:00    Thursday              31-50          Male
# ...         ...         ...                ...           ...
# 12302  17:25:00      Friday              31-50          Male
# 12303  12:48:00      Friday              31-50          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 8      Junior high school                Employee         Above 10yr
# 9      Junior high school                Employee              1-2yr
# ...

# %%
df['Number_of_casualties'].value_counts()#print the count value of the number casualtis
# Out:
# Number_of_casualties
# 1    1999
# 2     521
# 3     208
# 4      87
# 5      47
# 6      22
# 8       3
# 7       2
# Name: count, dtype: int64

# %%
df['Number_of_casualties'].max()#print the max value
# Out:
# 8

# %%
df.query('Number_of_casualties >= 4').head(7) # print if num of casualtise great then 4
# Out:
#          Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 72   11:02:00    Thursday              31-50          Male
# 389  15:08:00      Monday            Over 51          Male
# 457  11:30:00     Tuesday           Under 18          Male
# 458  11:30:00     Tuesday           Under 18          Male
# 459  11:30:00     Tuesday              31-50          Male
# 460  11:30:00     Tuesday              18-30          Male
# 463  20:55:00      Friday            Over 51          Male
#
#       Educational_level Vehicle_driver_relation Driving_experience  \
# 72   Junior high school                Employee             5-10yr
# 389  Junior high school                Employee         Above 10yr
# 457  Junior high school                Employee              2-5yr
# 458  Junior high school                Employee              1-2yr
# 459   Elementary school                Employee             5-10yr
# 460  Junior high school                Employee             5-10yr
# ...

# %%
df['Owner_of_vehicle'].value_counts()#print the count value of the owner
# Out:
# Owner_of_vehicle
# Owner           2573
# Governmental     228
# Organization      81
# Other              7
# Name: count, dtype: int64

# %%
df.hist(bins=5,figsize=(6,3));# these is a histogram for the int type of the df

# %%
sns.scatterplot(x='Age_band_of_driver',y='Number_of_casualties',data=df);
plt.title('The Age of driver of casualties ');# these scatter explen the relation of the age band and the number casualties

# %%
df['Number_of_vehicles_involved'].value_counts()##print the count value of the number vehicles involed
# Out:
# Number_of_vehicles_involved
# 2    1990
# 1     474
# 3     351
# 4      71
# 6       2
# 7       1
# Name: count, dtype: int64

# %%
df['Sex_of_driver'].value_counts().plot(kind='barh');
plt.title('Sex Driver');
plt.xlabel('Drive number')
plt.ylabel('Sex of the Driver');
# by useing this visualize barh to show the sex of the drive and how is the more then outher

# %%
sns.scatterplot(x='Number_of_vehicles_involved',y='Type_of_vehicle',data=df);
plt.title('The number of the vehicelse besd on the type'); # explen the relation of number involved (besd on the type)

# %%
df.corr(numeric_only=True)#print the corr of the numbric id df
sns.heatmap(df.corr(numeric_only=True));

# %%
num_Data=df.select_dtypes(np.number)# slect the data as number

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 8      17:20:00      Friday              18-30          Male
# 9      17:20:00      Friday              18-30          Male
# 12     17:45:00    Thursday              18-30          Male
# 13     17:45:00    Thursday              31-50          Male
# 14     17:45:00    Thursday              31-50          Male
# ...         ...         ...                ...           ...
# 12302  17:25:00      Friday              31-50          Male
# 12303  12:48:00      Friday              31-50          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 8      Junior high school                Employee         Above 10yr
# 9      Junior high school                Employee              1-2yr
# ...

# %%
Vehicle_driver=df[['Vehicle_driver_relation']]
Vehicle_driver.value_counts()# the encoding cat
# Out:
# Vehicle_driver_relation
# Employee                   2422
# Owner                       434
# Other                        32
# Unknown                       1
# Name: count, dtype: int64

# %%
x=df.drop(columns='Number_of_vehicles_involved')# chosse the x and the y from the data to trin the machin and testing
y=df[['Number_of_vehicles_involved']]

# %%
from sklearn.model_selection import train_test_split # using the sklearn liprare to trin and test the data

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train# show the train of the x withot the Number_of_vehicles_involved
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 7163  16:35:00   Wednesday              18-30          Male
# 3740   8:30:00   Wednesday              31-50          Male
# 4895  10:15:00    Thursday              31-50          Male
# 2533   7:30:00    Thursday              18-30          Male
# 9729  12:33:00     Tuesday              18-30          Male
# ...        ...         ...                ...           ...
# 6517  21:55:00    Saturday              18-30          Male
# 4359  13:46:00      Sunday              18-30          Male
# 4587  13:24:00   Wednesday              18-30          Male
# 5109   8:40:00   Wednesday            Unknown          Male
# 3370  11:52:00      Monday              31-50          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 7163   Elementary school                Employee             5-10yr
# 3740  Junior high school                Employee             5-10yr
# ...

# %%
x_train.isna().sum()# chaek for the null
# Out:
# Time                       0
# Day_of_week                0
# Age_band_of_driver         0
# Sex_of_driver              0
# Educational_level          0
# Vehicle_driver_relation    0
# Driving_experience         0
# Type_of_vehicle            0
# Owner_of_vehicle           0
# Service_year_of_vehicle    0
# Defect_of_vehicle          0
# Area_accident_occured      0
# Lanes_or_Medians           0
# Road_allignment            0
# Types_of_Junction          0
# Road_surface_type          0
# Road_surface_conditions    0
# Light_conditions           0
# Weather_conditions         0
# Type_of_collision          0
# Number_of_casualties       0
# Vehicle_movement           0
# Casualty_class             0
# Sex_of_casualty            0
# Age_band_of_casualty       0
# Casualty_severity          0
# Work_of_casuality          0
# Fitness_of_casuality       0
# Pedestrian_movement        0
# Cause_of_accident          0
# Accident_severity          0
# dtype: int64

# %%
sns.scatterplot(x='Age_band_of_driver',y='Cause_of_accident', data=x_train);
plt.title('The Driver Age of Accident');
plt.xlabel('Driver Age')
plt.ylabel('Accident Cause');
# explain relatin of the age with the Accident # what the age of draiver and what the reson of the accident

# %%
y_train
# Out:
#       Number_of_vehicles_involved
# 7163                            1
# 3740                            2
# 4895                            2
# 2533                            1
# 9729                            1
# ...                           ...
# 6517                            2
# 4359                            1
# 4587                            2
# 5109                            2
# 3370                            2
#
# [2311 rows x 1 columns]

# %%
y_train.hist(bins=10,figsize=(4,4));# by using a histogram for check the number of involved veicles

# %%
y_train.isna().sum() # check of the null for y_train
# Out:
# Number_of_vehicles_involved    0
# dtype: int64

# %%
from sklearn.pipeline import make_pipeline# using the pipelin for scaler and Encider
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

scaler=make_pipeline(StandardScaler())
cat_encod=make_pipeline(OneHotEncoder())

# %%
scaler.fit(num_Data)# fit the scaler from 1,0
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler())])

# %%
scaler.transform(num_Data)
# Out:
# array([[-0.01743785, -0.53306555],
#        [-0.01743785, -0.53306555],
#        [-0.01743785,  0.47414594],
#        ...,
#        [-1.5917488 , -0.53306555],
#        [-0.01743785, -0.53306555],
#        [-0.01743785, -0.53306555]])

# %%
cat_encod.fit_transform(Vehicle_driver)# fit the Encoding catagors Vehicle_driver_relation into 01
# Out:
# <2889x4 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2889 stored elements in Compressed Sparse Row format>

# %%
x_train
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 7163  16:35:00   Wednesday              18-30          Male
# 3740   8:30:00   Wednesday              31-50          Male
# 4895  10:15:00    Thursday              31-50          Male
# 2533   7:30:00    Thursday              18-30          Male
# 9729  12:33:00     Tuesday              18-30          Male
# ...        ...         ...                ...           ...
# 6517  21:55:00    Saturday              18-30          Male
# 4359  13:46:00      Sunday              18-30          Male
# 4587  13:24:00   Wednesday              18-30          Male
# 5109   8:40:00   Wednesday            Unknown          Male
# 3370  11:52:00      Monday              31-50          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 7163   Elementary school                Employee             5-10yr
# 3740  Junior high school                Employee             5-10yr
# ...

# %%
y_train
# Out:
#       Number_of_vehicles_involved
# 7163                            1
# 3740                            2
# 4895                            2
# 2533                            1
# 9729                            1
# ...                           ...
# 6517                            2
# 4359                            1
# 4587                            2
# 5109                            2
# 3370                            2
#
# [2311 rows x 1 columns]

# %%
from sklearn.compose import ColumnTransformer# using the column Transform to transforme the sacler number [Number_of_casualties] and the catagors ['Owner_of_vehicle']

Trans=ColumnTransformer([('num',scaler,['Number_of_casualties']),('cat',cat_encod,['Owner_of_vehicle'])])

# %%
x_train_procc=Trans.fit_transform(x_train)# after the pocccing  transforms

# %%
x_train_procc# print
# Out:
# array([[-0.53546853,  0.        ,  0.        ,  0.        ,  1.        ],
#        [-0.53546853,  0.        ,  0.        ,  0.        ,  1.        ],
#        [-0.53546853,  0.        ,  0.        ,  0.        ,  1.        ],
#        ...,
#        [ 0.48977404,  0.        ,  0.        ,  0.        ,  1.        ],
#        [-0.53546853,  0.        ,  0.        ,  0.        ,  1.        ],
#        [-0.53546853,  0.        ,  0.        ,  0.        ,  1.        ]])

# %%
from sklearn.linear_model import LinearRegression # using the liner modal

lin=LinearRegression()

# %%
lin.fit(x_train_procc,y_train)
# Out:
# LinearRegression()

# %%
lin.score(x_train_procc,y_train)# score
# Out:
# 0.050288676401828325

# %%
lin.coef_#w
# Out:
# array([[ 1.36156618e-01, -1.00838783e+13, -1.00838783e+13,
#         -1.00838783e+13, -1.00838783e+13]])

# %%
lin.intercept_#b
# Out:
# array([1.00838783e+13])

# %%
y_pre=lin.predict((x_train_procc))# predict
y_pre
# Out:
# array([[1.9375    ],
#        [1.9375    ],
#        [1.9375    ],
#        ...,
#        [2.07617188],
#        [1.9375    ],
#        [1.9375    ]])

# %% [markdown]
# <a href="https://colab.research.google.com/github/SadeemAlasiri/Exme/blob/main/Task_(1)_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %%
import pandas as pd
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/Task (1) Dataset.csv')

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isna()
# Out:
#         Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0      False        False               False          False
# 1      False        False               False          False
# 2      False        False               False          False
# 3      False        False               False          False
# 4      False        False               False          False
# ...      ...          ...                 ...            ...
# 12311  False        False               False          False
# 12312  False        False               False          False
# 12313  False        False               False          False
# 12314  False        False               False          False
# 12315  False        False               False          False
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                  False                    False               False
# 1                  False                    False               False
# ...

# %%
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df['Number_of_casualties'].fillna(df['Number_of_casualties'].mode)
df['Number_of_casualties'].isna().sum()
# Out:
# 0

# %%
df['Number_of_casualties']
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 12311    1
# 12312    1
# 12313    1
# 12314    1
# 12315    1
# Name: Number_of_casualties, Length: 12316, dtype: int64

# %%
df['Service_year_of_vehicle'].fillna(df['Service_year_of_vehicle'].mode)
df['Service_year_of_vehicle'].isna().sum()
# Out:
# 3928

# %%
df['Age_band_of_casualty'].fillna(df['Age_band_of_casualty'].mode)
df['Age_band_of_casualty'].isna().sum()
# Out:
# 0

# %%
df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode)
df['Type_of_vehicle'].isna().sum()
# Out:
# 950

# %%
df['Age_band_of_driver'].fillna(df['Age_band_of_driver'].mode)
df['Age_band_of_driver'].isna().sum()
# Out:
# 0

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df['Age_band_of_driver']

# %%
#df= pd.to_datetime(df['Time'])
print(df)
# Out:
# 0       2024-07-25 17:02:00
# 1       2024-07-25 17:02:00
# 2       2024-07-25 17:02:00
# 3       2024-07-25 01:06:00
# 4       2024-07-25 01:06:00
#                 ...
# 12311   2024-07-25 16:15:00
# 12312   2024-07-25 18:00:00
# 12313   2024-07-25 13:55:00
# 12314   2024-07-25 13:55:00
# 12315   2024-07-25 13:55:00
# Name: Time, Length: 12316, dtype: datetime64[ns]

# %%
df.drop('Fitness_of_casuality')

# %%
df['Sex_of_casualty'].fillna(df['Sex_of_casualty'].mod)
df['Sex_of_casualty'].isna().sum()
# Out:
# 0

# %%
df.fillna(value=1)
df
# Out:
# 0       2024-07-25 17:02:00
# 1       2024-07-25 17:02:00
# 2       2024-07-25 17:02:00
# 3       2024-07-25 01:06:00
# 4       2024-07-25 01:06:00
#                 ...
# 12311   2024-07-25 16:15:00
# 12312   2024-07-25 18:00:00
# 12313   2024-07-25 13:55:00
# 12314   2024-07-25 13:55:00
# 12315   2024-07-25 13:55:00
# Name: Time, Length: 12316, dtype: datetime64[ns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
#  Number_of_vehicles_involved
#  Number_of_casualties
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df[['Number_of_vehicles_involved','Number_of_casualties']].mean()
# Out:
# Number_of_vehicles_involved    2.040679
# Number_of_casualties           1.548149
# dtype: float64

# %%
df[['Number_of_vehicles_involved','Number_of_casualties']].sum()
# Out:
# Number_of_vehicles_involved    25133
# Number_of_casualties           19067
# dtype: int64

# %%
df[['Number_of_vehicles_involved','Number_of_casualties']].max()
# Out:
# Number_of_vehicles_involved    7
# Number_of_casualties           8
# dtype: int64

# %%
df[['Number_of_vehicles_involved','Number_of_casualties']].min()
# Out:
# Number_of_vehicles_involved    1
# Number_of_casualties           1
# dtype: int64

# %%
df[['Number_of_vehicles_involved','Number_of_casualties']].count()
# Out:
# Number_of_vehicles_involved    12316
# Number_of_casualties           12316
# dtype: int64

# %%
df[['Number_of_vehicles_involved','Number_of_casualties']].mode()
# Out:
#    Number_of_vehicles_involved  Number_of_casualties
# 0                            2                     1

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
df.iloc[3]
# Out:
# Time                                                                 1:06:00
# Day_of_week                                                           Sunday
# Age_band_of_driver                                                     18-30
# Sex_of_driver                                                           Male
# Educational_level                                         Junior high school
# Vehicle_driver_relation                                             Employee
# Driving_experience                                                    5-10yr
# Type_of_vehicle                                          Public (> 45 seats)
# Owner_of_vehicle                                                Governmental
# Service_year_of_vehicle                                                  NaN
# Defect_of_vehicle                                                  No defect
# Area_accident_occured                                           Office areas
# ...

# %%
df.iloc[5:4]
# Out:
# Empty DataFrame
# Columns: [Time, Day_of_week, Age_band_of_driver, Sex_of_driver, Educational_level, Vehicle_driver_relation, Driving_experience, Type_of_vehicle, Owner_of_vehicle, Service_year_of_vehicle, Defect_of_vehicle, Area_accident_occured, Lanes_or_Medians, Road_allignment, Types_of_Junction, Road_surface_type, Road_surface_conditions, Light_conditions, Weather_conditions, Type_of_collision, Number_of_vehicles_involved, Number_of_casualties, Vehicle_movement, Casualty_class, Sex_of_casualty, Age_band_of_casualty, Casualty_severity, Work_of_casuality, Fitness_of_casuality, Pedestrian_movement, Cause_of_accident, Accident_severity]
# Index: []
#
# [0 rows x 32 columns]

# %%
sns.barplot(df['Type_of_vehicle'],color='red')
# Out:
# <Axes: ylabel='Type_of_vehicle'>

# %%
sns.barplot(df['Age_band_of_driver'], color='pink')
# Out:
# <Axes: ylabel='Age_band_of_driver'>

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df1 =df.groupby(['Age_band_of_driver','Accident_severity']).agg(
    Total_Number_Driver=('Number_of_vehicles_involved','sum'),
       max_Number_Driver=('Number_of_vehicles_involved','max'),
       min_Number_Driver=('Number_of_vehicles_involved','min'),
       count_Number_Driver=('Number_of_vehicles_involved','count')
)
df1
# Out:
#                                       Total_Number_Driver  max_Number_Driver  \
# Age_band_of_driver Accident_severity
# 18-30              Fatal injury                       111                  3
#                    Serious Injury                    1155                  6
#                    Slight Injury                     7509                  6
# 31-50              Fatal injury                        99                  3
#                    Serious Injury                    1018                  6
#                    Slight Injury                     7142                  7
# Over 51            Fatal injury                        45                  3
#                    Serious Injury                     497                  6
#                    Slight Injury                     2678                  6
# Under 18           Fatal injury                        20                  3
#                    Serious Injury                     321                  4
# ...

# %% [markdown]
# ## 3. Data Visualization

# %%
df['Owner_of_vehicle'].head(10)
# Out:
# 0           Owner
# 1           Owner
# 2           Owner
# 3    Governmental
# 4           Owner
# 5             NaN
# 6           Owner
# 7    Governmental
# 8           Owner
# 9           Owner
# Name: Owner_of_vehicle, dtype: object

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
#visualization for the df1 = Total_Number_Driver	max_Number_Driver	min_Number_Driver	count_Number_Driver
#sns.pairplot(df1)

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Type_of_vehicle'],bins=25,color='red')
plt.title('histograms for Type_of_vehicle')
plt.xlabel('Type_vehicle')
plt.ylabel('number of Type_vehicle')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
sns.histplot(df['Sex_of_casualty'],bins=15,color='red')
plt.title('histograms for Sex')
plt.xlabel('Sex')
plt.ylabel('number_sex_casualties')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# 1- get information from the datafarm
#
# 2- in  the first char explen the Type of vehicle using bar plot to
#  see how much type do the data  have and what is the max,min of type
#
#  3- the second char using barpolt char it for explen the age band of driver from18-30 and 31-50and how is the under 18ond over 50 also the unkwon age these is for explen what shold the age band of driver

# %% [markdown]
# 4-the four char histograms it explen how many Type vehicle do data have and how much of vehicle of the type and what  vehicle type is the max and the min
#
# 5-the 5 char is histograms it explen Number of casualties and the sex  ther are a male an female in histograms explan thea male it more than the female in casualties

# %%
#1 get information from the datafarm
